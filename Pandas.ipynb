# %%
import pandas as pd
import numpy as np

# %%
forum_users = {
    'User ID': np.array([1, 2, 3, 4, 5]),
    'Username': ['jack', 'wilson', 'adam', 'jim', 'oscar'],
    'Age': [18, 23, 34, 45, None],
    'joined_date': pd.to_datetime(['2024-6-12', '2024-5-16', '2024-4-14', '2024-7-09', '2024-8-02']),
    'Total posts': [234, 345, 567, 678, 787],
    'Reputation': [700, 545, 565, 766, 234]
}

df = pd.DataFrame(forum_users)
df
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 0        1     jack  18.0  2024-06-12          234         700
# 1        2   wilson  23.0  2024-05-16          345         545
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766
# 4        5    oscar   NaN  2024-08-02          787         234

# %%
df['Age'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
df.loc[3] # We will get here just one row or a 1 Series.
# Out:
# User ID                          4
# Username                       jim
# Age                           45.0
# joined_date    2024-07-09 00:00:00
# Total posts                    678
# Reputation                     766
# Name: 3, dtype: object

# %%
df.loc[2:3] # We will get here just 2-D in a Series (rows and columns)
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766

# %%
# LOC works with labels: integer and string
df.loc[2:3, ['Username', 'Age', 'Reputation']] # Here we get the first row and then a column name.
# Out:
#   Username   Age  Reputation
# 2     adam  34.0         565
# 3      jim  45.0         766

# %%
df.iloc[2:4] # Here we exclude for the rows and columns 4 meaning we will get in this case from 2 to 3.
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766

# %%
df.iloc[2:4, 1:4] # 2:4 is rows and 1:4 index of the columns.
# Out:
#   Username   Age joined_date
# 2     adam  34.0  2024-04-14
# 3      jim  45.0  2024-07-09

# %%
df[df['Age'] >= 25] # Here is an expression of how we get the values of the data.
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766

# %%
date_range = pd.date_range(start='2024-01-01', end='2024-12-31')
date_range
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2024-12-22', '2024-12-23', '2024-12-24', '2024-12-25',
#                '2024-12-26', '2024-12-27', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
df[df['joined_date'].isin(date_range)]
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 0        1     jack  18.0  2024-06-12          234         700
# 1        2   wilson  23.0  2024-05-16          345         545
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766
# 4        5    oscar   NaN  2024-08-02          787         234

# %%
# SORTING
df.sort_values(by='Age')
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 0        1     jack  18.0  2024-06-12          234         700
# 1        2   wilson  23.0  2024-05-16          345         545
# 2        3     adam  34.0  2024-04-14          567         565
# 3        4      jim  45.0  2024-07-09          678         766
# 4        5    oscar   NaN  2024-08-02          787         234

# %%
df[df['Reputation'].isin([700, 500])]
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation
# 0        1     jack  18.0  2024-06-12          234         700

# %%
df1 = {
    'total comments': [1, 2, 3, 4, 5]
}
df2 = pd.DataFrame(df1)
df2
# Out:
#    total comments
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5

# %%
df['Language'] = 'English'
df
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation Language
# 0        1     jack  18.0  2024-06-12          234         700  English
# 1        2   wilson  23.0  2024-05-16          345         545  English
# 2        3     adam  34.0  2024-04-14          567         565  English
# 3        4      jim  45.0  2024-07-09          678         766  English
# 4        5    oscar   NaN  2024-08-02          787         234  English

# %%
# Merging my calling the method concat([]) from the pandas and passing the arguments in the list.
# pd.concat([]) works only with axis=0!!!
pd.concat([df, df2], axis=0)
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation Language  \
# 0      1.0     jack  18.0  2024-06-12        234.0       700.0  English
# 1      2.0   wilson  23.0  2024-05-16        345.0       545.0  English
# 2      3.0     adam  34.0  2024-04-14        567.0       565.0  English
# 3      4.0      jim  45.0  2024-07-09        678.0       766.0  English
# 4      5.0    oscar   NaN  2024-08-02        787.0       234.0  English
# 0      NaN      NaN   NaN         NaT          NaN         NaN      NaN
# 1      NaN      NaN   NaN         NaT          NaN         NaN      NaN
# 2      NaN      NaN   NaN         NaT          NaN         NaN      NaN
# 3      NaN      NaN   NaN         NaT          NaN         NaN      NaN
# 4      NaN      NaN   NaN         NaT          NaN         NaN      NaN
#
#    total comments
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 0             1.0
# 1             2.0
# 2             3.0
# ...

# %%
df = pd.concat([df, df2], axis=1)
df
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation Language  \
# 0        1     jack  18.0  2024-06-12          234         700  English
# 1        2   wilson  23.0  2024-05-16          345         545  English
# 2        3     adam  34.0  2024-04-14          567         565  English
# 3        4      jim  45.0  2024-07-09          678         766  English
# 4        5    oscar   NaN  2024-08-02          787         234  English
#
#    total comments
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5

# %%
# Original df doesn't change
df.drop('Language', axis=1)
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation  total comments
# 0        1     jack  18.0  2024-06-12          234         700               1
# 1        2   wilson  23.0  2024-05-16          345         545               2
# 2        3     adam  34.0  2024-04-14          567         565               3
# 3        4      jim  45.0  2024-07-09          678         766               4
# 4        5    oscar   NaN  2024-08-02          787         234               5

# %%
# Original df is changed in place
df.drop('Language', axis=1, inplace=True)
df
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation  total comments
# 0        1     jack  18.0  2024-06-12          234         700               1
# 1        2   wilson  23.0  2024-05-16          345         545               2
# 2        3     adam  34.0  2024-04-14          567         565               3
# 3        4      jim  45.0  2024-07-09          678         766               4
# 4        5    oscar   NaN  2024-08-02          787         234               5

# %%
# Delete the row. And by passing the argument inplace=True means that we change the ORIGINAL df.
df.drop([2, 3], inplace=True) # We pass the argument in the list or array
df
# Out:
#    User ID Username   Age joined_date  Total posts  Reputation  total comments
# 0        1     jack  18.0  2024-06-12          234         700               1
# 1        2   wilson  23.0  2024-05-16          345         545               2
# 4        5    oscar   NaN  2024-08-02          787         234               5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.random.seed(1)
n = 100
dates = pd.date_range(start='2050-01-01', periods=n, freq='D')
products = np.random.choice(['Tablet', 'Camera', 'Phone'], n)
prices = np.round(np.random.uniform(50.0, 200.0, n), 2)
quantities = np.random.randint(1, 15, n)

data = {
    'Data': dates,
    'Product': products,
    'Price': prices,
    'Quantity': quantities
}

df = pd.DataFrame(data)
df.head()
# Out:
#         Data Product   Price  Quantity
# 0 2050-01-01  Camera  191.69         2
# 1 2050-01-02  Tablet  137.98         8
# 2 2050-01-03  Tablet  185.51         1
# 3 2050-01-04  Camera   70.62        11
# 4 2050-01-05  Camera   70.89        11

# %%
df.dtypes
# Out:
# Data        datetime64[ns]
# Product             object
# Price              float64
# Quantity             int64
# dtype: object

# %%
df.to_csv('random_sales.csv', index=False)

# %%
import pandas as pd

# Create a DataFrame from a list of lists
data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'Los Angeles'],
    ['Charlie', 35, 'Chicago']
]

columns = ['Name', 'Age', 'City']

df = pd.DataFrame(data, columns=columns)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
import pandas as pd

# Sample data for demonstration
data = {
    'Product': ['Camera', 'Phone', 'Tablet', 'Camera', 'Phone', 'Tablet'],
    'Quantity': [50, 120, 200, 210, 169, 188]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Group by 'Product' and sum the 'Quantity'
result = df.groupby('Product')['Quantity'].sum()

# Display the result
print(result)
# Out:
# Product
# Camera    260
# Phone     289
# Tablet    388
# Name: Quantity, dtype: int64
